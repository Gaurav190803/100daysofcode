# %% [markdown]
# First step lets pre process our data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Salary_Data.csv")
X = dataset.iloc[:,:-1].values
Y = dataset.iloc[:,-1].values

# %% [markdown]
# Splitting the dataset into test and train

# %%
from sklearn.model_selection import train_test_split
X_train , X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2,random_state = 0)

# %% [markdown]
# Feature scaling is not required as we only have one feature

# %% [markdown]
# Pre processing done
#
# MACHINE LEARNING
# SIMPLE LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()                                                        #initializing the linear regressor class
regressor.fit(X_train,Y_train)                                                        #training the model on sample datatset
y_pred = regressor.predict(X_test)                                                    #predicting test results

# %% [markdown]
# Plotting graphs to compare results

# %%
plt.scatter(X_train,Y_train,color = 'red')
plt.plot(X_train,regressor.predict(X_train),color = 'blue')
plt.title("Experience vs Salary {training set}")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(X_test,Y_test,color = 'red')
plt.plot(X_train,regressor.predict(X_train),color = 'blue')
plt.title("Experience vs Salary {training set}")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.show()

# %%
print(regressor.predict([[12]]))            #predict always expects a 2d array
# Out:
# [138531.00067138]

# %%
print(regressor.coef_)        #b1             linear regression equation
print(regressor.intercept_)   #b0             y    =    b0     +    b1   .   (x)
                              #             label    intercept     coeff  feature
# Out:
# [9312.57512673]
# 26780.09915062818
